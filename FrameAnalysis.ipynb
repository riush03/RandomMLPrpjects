# %%
# !pip install anastruct
# Out:
# Collecting anastruct
#   Downloading anastruct-1.4.2-py3-none-any.whl (264 kB)
#      ------------------------------------ 264.8/264.8 kB 346.8 kB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.1.0 in c:\users\snowee\appdata\local\anaconda3\lib\site-packages (from anastruct) (1.10.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\snowee\appdata\local\anaconda3\lib\site-packages (from anastruct) (1.23.5)
# Installing collected packages: anastruct
# Successfully installed anastruct-1.4.2

# %%
from anastruct import SystemElements

# %%
ss =  SystemElements()

# %%
ss.add_element(location=[[0,0],[0,2]])
ss.add_element(location=[[0,2],[0,4]])
ss.add_element(location=[[0,4],[3,4]])
ss.add_element(location=[[3,4],[4,4]])
ss.add_element(location=[[4,4],[6,4]])
ss.add_element(location=[[6,4],[7,4]])
# Out:
# 6

# %%
#derfine hinges
ss.add_internal_hinge(node_id=3)
ss.add_internal_hinge(node_id=5)

# %%
#support conditions => the frame has three supports
ss.add_support_fixed(node_id=1)
ss.add_support_fixed(node_id=4)
ss.add_support_fixed(node_id=6)

# %%
#add external forces to the structure
ss.point_load(node_id=2,Fx=+5)
ss.q_load(q=-2,element_id=3)
ss.q_load(q=-2,element_id=4)
ss.point_load(node_id=7,Fx=-10)

# %%
ss.solve()
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  6.15384615e-04,
#         2.50515527e-04, -1.53846154e-04,  3.07692308e-04,  5.01031053e-04,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -2.72143733e-21,  3.33333417e-05,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -6.66666667e-04,  0.00000000e+00,
#         0.00000000e+00])

# %%
ss.show_reaction_force()

# %%
ss.show_bending_moment()

# %%
ss.show_shear_force()
